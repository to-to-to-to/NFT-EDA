# %% [markdown]
# ## I. About This Project

# %% [markdown]
# In This Project, From The NFT Collection Dataset (https://www.kaggle.com/nenamalikah/nft-collections-by-sales-volume), I want to do the <b>Exploratory Data Analysis</b> about it using Data Manipulation Libraries such as <b>Numpy, Pandas, and Plotly</b>. The goal of this project is I want to <b>Give Insights from the dataset about the NFT Stats</b>, so after you reading this you will gain informations from the report provided about the NFT.

# %% [markdown]
# ![Screenshot%202022-02-27%20161343.png](attachment:Screenshot%202022-02-27%20161343.png)

# %% [markdown]
# For Related Libraries Documentations that I used in this project, you can access through this link :
#
# - <b>Numpy</b> : https://numpy.org/
# - <b>Pandas</b> : https://pandas.pydata.org/
# - <b>Plotly</b> : https://plotly.com/

# %% [markdown]
# ## II. What is EDA?

# %% [markdown]
# Exploratory Data Analysis refers to the <b>critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations</b>. (source = https://towardsdatascience.com/exploratory-data-analysis-8fc1cb20fd15)

# %% [markdown]
# <img src = "https://miro.medium.com/max/1816/1*yY5jSLXWZ4d2H6tVtKRSGg.png" style = "width:400px; height: 370px">

# %% [markdown]
# ## III. Plan of Attack

# %% [markdown]
# In this project, There are 3 Major Steps in order to get the result using CNN, which are :
#
# - <b>Data Wrangling & Cleaning</b>
# - <b>Visualize the Data with Plotly</b>
# - <b>Conclusion</b>

# %% [markdown]
# ### Step 1 : Data Wrangling & Cleaning

# %%
#import libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import cufflinks as cf
import chart_studio.plotly as py
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected = True)
cf.go_offline()
import plotly.io as pio
pio.renderers.default = 'notebook_connected'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
#load dataset

df = pd.read_csv("dataset/NFT_Top_Collections.csv")
df.head(10)
# Out:
#    Index                               Name    Volume    Volume_USD  \
# 0      0                      basis.markets  27256.63  4.001818e+06
# 1      1               Skeleton Crew Skulls  11381.25  1.670995e+06
# 2      2                           Flippies   6732.19  9.884201e+05
# 3      3  Meerkat Millionaires Country Club   3734.76  5.483375e+05
# 4      4                      Stylish Studs   3191.15  4.685246e+05
# 5      5                           I'M AIKO   2904.70  4.264681e+05
# 6      6                       Crypto Idolz   2315.74  3.399969e+05
# 7      7        Megalodon Rogue Shark Tooth   2116.61  3.107607e+05
# 8      8                        CorruptCatz   1983.92  2.912791e+05
# 9      9                        Meta Waifus   1844.59  2.708227e+05
#
#     Market_Cap  Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  \
# 0   708.145455   103969.915600    366        39.50        5799.3900
# 1   106.656000    15659.233920   2075         0.67          98.3694
# ...

# %%
# find missing values
df.isnull().sum()
# Out:
# Index                  0
# Name                   0
# Volume                 0
# Volume_USD             0
# Market_Cap             0
# Market_Cap_USD         0
# Sales                  0
# Floor_Price           48
# Floor_Price_USD       48
# Average_Price          0
# Average_Price_USD      0
# Owners                 0
# Assets                 0
# Owner_Asset_Ratio     49
# Category             282
# Website              111
# Logo                   1
# dtype: int64

# %%
#find percentage of missing values
df.isnull().sum()/len(df)*100
# Out:
# Index                 0.000000
# Name                  0.000000
# Volume                0.000000
# Volume_USD            0.000000
# Market_Cap            0.000000
# Market_Cap_USD        0.000000
# Sales                 0.000000
# Floor_Price           8.108108
# Floor_Price_USD       8.108108
# Average_Price         0.000000
# Average_Price_USD     0.000000
# Owners                0.000000
# Assets                0.000000
# Owner_Asset_Ratio     8.277027
# Category             47.635135
# Website              18.750000
# Logo                  0.168919
# dtype: float64

# %%
# quick summary about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              592 non-null    int64
#  1   Name               592 non-null    object
#  2   Volume             592 non-null    float64
#  3   Volume_USD         592 non-null    float64
#  4   Market_Cap         592 non-null    float64
#  5   Market_Cap_USD     592 non-null    float64
#  6   Sales              592 non-null    int64
#  7   Floor_Price        544 non-null    float64
#  8   Floor_Price_USD    544 non-null    float64
#  9   Average_Price      592 non-null    float64
#  10  Average_Price_USD  592 non-null    float64
#  11  Owners             592 non-null    int64
#  12  Assets             592 non-null    int64
#  13  Owner_Asset_Ratio  543 non-null    float64
#  14  Category           310 non-null    object
#  15  Website            481 non-null    object
# ...

# %%
# quick summary about numeric values

df[['Volume', 'Volume_USD',
    'Market_Cap', 'Market_Cap_USD',
    'Sales', 'Floor_Price',
    'Floor_Price_USD', 'Average_Price',
    'Average_Price_USD', 'Owners', 'Assets',
    'Owner_Asset_Ratio']].describe()
# Out:
#              Volume    Volume_USD   Market_Cap  Market_Cap_USD        Sales  \
# count    592.000000  5.920000e+02   592.000000      592.000000   592.000000
# mean     197.548885  2.900413e+04    45.134817     6626.693810   164.491554
# std     1283.031435  1.883747e+05   179.327166    26328.814578   451.321395
# min        0.000000  0.000000e+00     0.000000        0.000000     0.000000
# 25%        7.300000  1.071786e+03     0.000000        0.000000    11.000000
# 50%       18.595000  2.730118e+03     0.000000        0.000000    35.000000
# 75%       80.825000  1.186673e+04    21.841974     3206.838576   107.250000
# max    27256.630000  4.001818e+06  2530.877143   371583.382100  5229.000000
#
#        Floor_Price  Floor_Price_USD  Average_Price  Average_Price_USD  \
# count   544.000000       544.000000     592.000000         592.000000
# mean      2.423015       355.747019       2.373566         348.486991
# std      18.982148      2786.959001      15.035229        2207.472329
# ...

# %%
# exclude columns (index, website, and logo)

df_new = df[['Name', 'Volume', 'Volume_USD',
    'Market_Cap', 'Market_Cap_USD',
    'Sales', 'Floor_Price',
    'Floor_Price_USD', 'Average_Price',
    'Average_Price_USD', 'Owners', 'Assets',
    'Owner_Asset_Ratio', 'Category']]
df_new.Category = df_new.Category.fillna('Unknown')
df_new
# Out:
#                                   Name    Volume    Volume_USD   Market_Cap  \
# 0                        basis.markets  27256.63  4.001818e+06   708.145455
# 1                 Skeleton Crew Skulls  11381.25  1.670995e+06   106.656000
# 2                             Flippies   6732.19  9.884201e+05  1663.863158
# 3    Meerkat Millionaires Country Club   3734.76  5.483375e+05    90.275000
# 4                        Stylish Studs   3191.15  4.685246e+05   165.000000
# ..                                 ...       ...           ...          ...
# 587                NEO MONKEY BUSINESS      0.00  0.000000e+00     0.000000
# 588                          Cops Game      0.00  0.000000e+00     0.000000
# 589                   Floppa Syndicate      0.00  0.000000e+00     0.000000
# 590                           Duck BRO      0.00  0.000000e+00     0.000000
# 591                         CryptoPets      0.00  0.000000e+00     0.000000
#
# ...

# %%
df_top10 = df_new.head(10)

fig = px.bar(df_top10, 
             x = 'Name',
             y = 'Volume',
             text = 'Volume',
             color = 'Name',
             title = 'Comparison of Volume of Top 10 NFT on the market',
             labels = {'Volume' : 'Volume', 'Name' : 'NFT Name'})
fig.update_traces(texttemplate = '%{text:.3s}', textposition = 'outside')
fig.update_layout(uniformtext_minsize = 9)
fig.update_layout(xaxis_tickangle =-45)
fig.update_layout(yaxis_range = [0,35000])

fig.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
fig = px.bar(df_top10, 
             x = 'Name',
             y = 'Volume_USD',
             text = 'Volume_USD',
             color = 'Name',
             title = 'Comparison of Volume USD of Top 10 NFT on the market',
             labels = {'Volume_USD' : 'Volume USD', 'Name' : 'NFT Name'})
fig.update_traces(texttemplate = '%{text:.3s}', textposition = 'outside')
fig.update_layout(uniformtext_minsize = 9)
fig.update_layout(xaxis_tickangle =-45)
fig.update_layout(yaxis_range = [0,4500000])

fig.show(renderer='notebook_connected')
# Out:
# <div>                            <div id="bd864dc5-72ff-4d2e-a535-e6fddb8259e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd864dc5-72ff-4d2e-a535-e6fddb8259e4")) {                    Plotly.newPlot(                        "bd864dc5-72ff-4d2e-a535-e6fddb8259e4",                        [{"alignmentgroup":"True","hovertemplate":"NFT Name=%{x}<br>Volume USD=%{text}<extra></extra>","legendgroup":"basis.markets","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"basis.markets","offsetgroup":"basis.markets","orientation":"v","showlegend":true,"text":[4001818.417],"textposition":"outside","x":["basis.markets"],"xaxis":"x","y":[4001818.417],"yaxis":"y","type":"bar","texttemplate":"%{text:.3s}"},{"alignmentgroup":"True","hovertemplate":"NFT Nam
# ...

# %%
fig = px.bar(df_top10, 
             x = 'Name',
             y = 'Market_Cap',
             text = 'Market_Cap',
             color = 'Name',
             title = 'Comparison of Market Cap of Top 10 NFT on the market',
             labels = {'Market_Cap' : 'Market Cap', 'Name' : 'NFT Name'})
fig.update_traces(texttemplate = '%{text:.3s}', textposition = 'outside')
fig.update_layout(uniformtext_minsize = 9)
fig.update_layout(xaxis_tickangle =-45)
fig.update_layout(yaxis_range = [0,3500])

fig.show(renderer='notebook_connected')
# Out:
# <div>                            <div id="b1c04417-ea2e-433f-b531-788e33ef94ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1c04417-ea2e-433f-b531-788e33ef94ed")) {                    Plotly.newPlot(                        "b1c04417-ea2e-433f-b531-788e33ef94ed",                        [{"alignmentgroup":"True","hovertemplate":"NFT Name=%{x}<br>Market Cap=%{text}<extra></extra>","legendgroup":"basis.markets","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"basis.markets","offsetgroup":"basis.markets","orientation":"v","showlegend":true,"text":[708.1454545],"textposition":"outside","x":["basis.markets"],"xaxis":"x","y":[708.1454545],"yaxis":"y","type":"bar","texttemplate":"%{text:.3s}"},{"alignmentgroup":"True","hovertemplate":"NFT Nam
# ...

# %%
fig = px.bar(df_top10, 
             x = 'Name',
             y = 'Market_Cap_USD',
             text = 'Market_Cap_USD',
             color = 'Name',
             title = 'Comparison of Market Cap USD of Top 10 NFT on the market',
             labels = {'Market_Cap_USD' : 'Market Cap USD', 'Name' : 'NFT Name'})
fig.update_traces(texttemplate = '%{text:.3s}', textposition = 'outside')
fig.update_layout(uniformtext_minsize = 9)
fig.update_layout(xaxis_tickangle =-45)
fig.update_layout(yaxis_range = [0,450000])

fig.show(renderer='notebook_connected')
# Out:
# <div>                            <div id="1d1cefd0-8908-467c-9536-b09f4dec9c7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d1cefd0-8908-467c-9536-b09f4dec9c7b")) {                    Plotly.newPlot(                        "1d1cefd0-8908-467c-9536-b09f4dec9c7b",                        [{"alignmentgroup":"True","hovertemplate":"NFT Name=%{x}<br>Market Cap USD=%{text}<extra></extra>","legendgroup":"basis.markets","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"basis.markets","offsetgroup":"basis.markets","orientation":"v","showlegend":true,"text":[103969.9156],"textposition":"outside","x":["basis.markets"],"xaxis":"x","y":[103969.9156],"yaxis":"y","type":"bar","texttemplate":"%{text:.3s}"},{"alignmentgroup":"True","hovertemplate":"NFT
# ...

# %%
fig = px.histogram(df, x="Owners")
fig.show(renderer='notebook_connected')
# Out:
# <div>                            <div id="fe6b06f2-062a-434e-a3a7-1c7cbc76a91a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe6b06f2-062a-434e-a3a7-1c7cbc76a91a")) {                    Plotly.newPlot(                        "fe6b06f2-062a-434e-a3a7-1c7cbc76a91a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Owners=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[12,103,905,19,28,599,244,946,636,376,413,5,243,99,123,388,12,285,14,706,29,89,194,38,86,0,0,2041,35,304,136,18,73,0,15,42,141,0,29,46,171,0,179,56,330,330,5,113,34,8,39,15,404,50,6,317,114,338,3,7,4,73,99,3,162,72,75,58,169,44,45,
# ...

# %%
fig = px.histogram(df, x="Assets")
fig.show(renderer='notebook_connected')
# Out:
# <div>                            <div id="140d1039-787a-4dd1-820b-e08c0f185cef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("140d1039-787a-4dd1-820b-e08c0f185cef")) {                    Plotly.newPlot(                        "140d1039-787a-4dd1-820b-e08c0f185cef",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Assets=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[16,132,1638,23,50,1206,529,1309,916,643,847,6,391,127,175,1239,13,419,15,1242,29,128,272,51,122,0,1,3320,58,451,212,28,94,0,466,52,427,0,45,183,504,0,319,860,793,516,14,803,38,8,63,15,865,185,963,341,162,585,3,46,4,114,210,4,270,9
# ...

# %%
fig = px.scatter(df_new,
           x = 'Sales',
           y = 'Owners',
           color = 'Category',
           size = 'Assets',
           hover_data = ['Owner_Asset_Ratio'])

fig.show(renderer='notebook_connected')
# Out:
# <div>                            <div id="5bec9963-e24f-4f7a-8d9c-1cbefb19b313" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bec9963-e24f-4f7a-8d9c-1cbefb19b313")) {                    Plotly.newPlot(                        "5bec9963-e24f-4f7a-8d9c-1cbefb19b313",                        [{"customdata":[[75.0]],"hovertemplate":"Category=Collectibles,Digital,Privilege<br>Sales=%{x}<br>Owners=%{y}<br>Assets=%{marker.size}<br>Owner_Asset_Ratio=%{customdata[0]}<extra></extra>","legendgroup":"Collectibles,Digital,Privilege","marker":{"color":"#636efa","size":[16],"sizemode":"area","sizeref":8.3,"symbol":"circle"},"mode":"markers","name":"Collectibles,Digital,Privilege","orientation":"v","showlegend":true,"x":[366],"xaxis":"x","y":[12],"yaxis":"y","type
# ...

# %%
fig = px.scatter(df_new,
           x = 'Floor_Price_USD',
           y = 'Average_Price_USD',
           color = 'Category')
fig.update_layout(yaxis_range = [0,15000])

fig.show(renderer='notebook_connected')
# Out:
# <div>                            <div id="691c30c3-a271-41fd-8029-50df31b64a20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("691c30c3-a271-41fd-8029-50df31b64a20")) {                    Plotly.newPlot(                        "691c30c3-a271-41fd-8029-50df31b64a20",                        [{"hovertemplate":"Category=Collectibles,Digital,Privilege<br>Floor_Price_USD=%{x}<br>Average_Price_USD=%{y}<extra></extra>","legendgroup":"Collectibles,Digital,Privilege","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Collectibles,Digital,Privilege","orientation":"v","showlegend":true,"x":[5799.39],"xaxis":"x","y":[10933.9301],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Unknown<br>Floor_Price_USD=%{x}<br>Average_Price_USD=%{y
# ...
